# %% [markdown]
# ## Setting up a 2D atmospheric simulation case: Colliding thermals test case
#
# ### Introduction
#
# This case considers the collision of a cold bubble and a warm bubble inside a neutrally stable hydrostatic atmosphere. It was designed by Norman (2021) to create stronger discontinuities, stronger winds, and more significant turbulence than the usual benchmark cases. The linear initial motion of the bubbles suddenly evolves into a nonlinear phenomenon, eventually producing a fully turbulent field.
#
# For this case, the background equilibrium state is the adiabatic equilibrium
# \begin{equation}
#         p^e=p_0\left(1-\frac{(\gamma -1)g}{\gamma R\theta_0}z   \right)^{\frac{\gamma }{\gamma -1}} \,,\quad   \rho^e=\frac{p}{R\pi\theta}= \frac{p_0}{R\theta_0}\left(1-\frac{(\gamma -1)g}{\gamma R\theta_0}z   \right)^{\frac{1}{\gamma -1}} \,,\quad w^e=0\,,
# \end{equation}
# with
# \begin{equation}
# p_0=10^5 \mbox{ Pa}\,,  \quad \theta_0=300 \mbox{ K}\,, \quad R=287.058\mbox{ kJ/kgK}\,,\quad \gamma=1.4\,,\quad g=9.8\mbox{ m/s$^2$.}
# \end{equation}
# It should be noted that the background potential temperature is constant, which produces a neutrally stable atmosphere.
#
# The problem is defined inside the domain $[0,20000]\times [0,10000]$ m$^2$. To drive the motion, we add a perturbation in the potential temperature in the form of a cold and a warm bubble
# \begin{equation}
# \Delta \theta=20(\max(1-d_1,0)+\min(d_2-1,0));
# \end{equation}
# with
# \begin{equation}
# d_1=\frac{\sqrt{(x-x_1)^2+(z-z_1)^2}}{r}\,,\quad d_2=\frac{\sqrt{(x-x_2)^2+(z-z_2)^2}}{r}\,,
# \end{equation}
# where $r=2000$ m is the radius of the bubbles, $(x_1,z_1)=(10000,2000)$ m is the center of the warm bubble and $(x_2,z_2)=(10000,8000)$ m is the center of the cold bubble.
#
# References:
#
# - Norman, M. R. (2021). A high‐order WENO‐limited finite‐volume algorithm for atmospheric flow using the ADER‐differential transform time discretization. Quarterly Journal of the Royal Meteorological Society, 147(736), 1661-1690.
#
#
# ### Importing required libraries
#
# Some of these are well known libraries such as *numpy* and *matplotlib* (they can be installed using pip). We also need to import the library *utils* containing predefined functionalities for this software.

# %%
import os
import math                    
import numpy as np             
import matplotlib.pyplot as plt 
import re
from glob import glob
from utils import modify_header_file,write_config,write_initial,write_equilibrium,backup_file,restore_file,compile_program,compile_program_jupyter,run_program,initialize_variables,read_data_euler
import imageio

# %% [markdown]
# ### Setting up the paths
#
# First, the name of the folder for this test case must be specified:

# %%
#This test case will run in the folder "caseCollidingBub/". 
#Don't forget the bar (/). 
folder_case="caseCollidingBub/"

# %% [markdown]
# Then, all the paths are automatically assigned, directories created and previous files removed:

# %%
#Do not modify the folders and paths below
script_dir = os.getcwd()
folder_out="out/"
folder_lib="lib"
fname_config="configure.input"
fname_eq="equilibrium.out"
fname_ini="initial.out"
folder_out = os.path.join(script_dir, "../"+folder_case+"/"+folder_out)
folder_case = os.path.join(script_dir, "../"+folder_case)
folder_lib = os.path.join(script_dir, "../"+folder_lib)
folder_exe = os.path.join(script_dir, "../")
os.makedirs(folder_case, exist_ok=True)
os.makedirs(folder_out, exist_ok=True)
for f in glob(folder_out + "/*.out") + glob(folder_out + "/*.vtk") + glob(folder_out + "/*.png"):
    os.remove(f)

# %% [markdown]
# ### Setting up the compilation variables (*definitions.h*)
#
# Here, we can modify those variables that need to be set before compilation and are found in the file *definitions.h*. Don't worry if you mess up things here, a backup of the original file is created before modification and will be restored at the end of this script, after compilation and execution.

# %%
#Do not change the line below, it creates a backup of the definitions.h file
backup_file(folder_lib+'/definitions.h')
#Configure the header file for compilation. Add as many lines as desired for the macros you want to modify.
modify_header_file(folder_lib+'/definitions.h', 'NTRHEADS', 2)         #number of threads
modify_header_file(folder_lib+'/definitions.h', 'EQUATION_SYSTEM', 2)  #System of equations solved
modify_header_file(folder_lib+'/definitions.h', 'ST', 3)               #Source term type
modify_header_file(folder_lib+'/definitions.h', 'SOLVER', 0)           #Riemann solver used
modify_header_file(folder_lib+'/definitions.h', 'READ_INITIAL', 1)     #Read or not initial data, this should ALWAYS be 1
# Out:
# Backup created at /home/pc/Escritorio/pr/EHOW3D_public/python/../lib/definitions.h.bak
# NTRHEADS changed to 2 in /home/pc/Escritorio/pr/EHOW3D_public/python/../lib/definitions.h
# EQUATION_SYSTEM changed to 2 in /home/pc/Escritorio/pr/EHOW3D_public/python/../lib/definitions.h
# ST changed to 3 in /home/pc/Escritorio/pr/EHOW3D_public/python/../lib/definitions.h
# SOLVER changed to 0 in /home/pc/Escritorio/pr/EHOW3D_public/python/../lib/definitions.h
# READ_INITIAL changed to 1 in /home/pc/Escritorio/pr/EHOW3D_public/python/../lib/definitions.h

# %% [markdown]
# ### Configure the global simulation parameters
#
# We can set the global simulation parameters as desired:

# %%
#Simulation setup
FinalTime = 800.0
DumpTime = 100.0  #for file printing
CFL = 0.45
Order = 7

#Mesh setup
xcells = 100
ycells = 1
zcells = 50
SizeX = 20000.0
SizeY = 1000.0
SizeZ = 10000.0

#Boundary conditions
Face_1 = 4 #-y
Face_2 = 4 #+x
Face_3 = 4 #+y
Face_4 = 4 #-x
Face_5 = 4 #-z
Face_6 = 4 #+z

#Linear transport, only if applicable
u_x = 1.0
u_y = 1.0
u_z = 1.0

# %% [markdown]
# ### Define the initial condition
#
# To define the initial condition we first need to create the arrays and initialize some variables:

# %%
xc, yc, zc, u, v, w, rho, p, phi, ue, ve, we, rhoe, pe = initialize_variables(xcells, ycells, zcells, SizeX, SizeY, SizeZ)

# %% [markdown]
# Among these, we have:
# - the problem variables: ```u, v, w, rho, p, phi```
# - the equilibrium variables (for atmospheric cases only): ```ue, ve, we, rhoe, pe```
#
# Then we can set the initial condition using those variables. To do this, we loop over the three cartesian indexes $(l,m,n)$ and assign the variables, e.g. $\rho(x_l,y_m,z_n)=...$ is set as ```rho[l,m,n]=...```. Cell centers are given by: ```xc[l,m,n]```, ```yc[l,m,n]``` and ```zc[l,m,n]```.

# %%
#Some auxiliary parameters (must be equal to those in definitions.h)
tt0=300
p0=1.e5
R=287.058
gamma=1.4
g=9.8
rho0=p0/(R*tt0)
aux2=(gamma-1.0)/gamma*g/(R*tt0)

#Initial condition and equilibrium state            
for l in range(0,xcells): 
        for m in range(0,ycells): 
            for n in range(0,zcells):
                
                #This is the equilibrium state (in this case, adiabatic equilibrium):
                rhoe[l,m,n]=rho0*(1.0-aux2*zc[l,m,n])**(1.0/(gamma-1.0))
                pe  [l,m,n]=p0*  (1.0-aux2*zc[l,m,n])**(gamma/(gamma-1.0))
                ue  [l,m,n]=0.0
                ve  [l,m,n]=0.0
                we  [l,m,n]=0.0
                
                #This is the initial condition
                xp=10000;
                zp=2000;
                d1=np.sqrt((xc[l,m,n]-xp)*(xc[l,m,n]-xp)+(zc[l,m,n]-zp)*(zc[l,m,n]-zp));

                xp=10000;
                zp=8000;
                d2=np.sqrt((xc[l,m,n]-xp)*(xc[l,m,n]-xp)+(zc[l,m,n]-zp)*(zc[l,m,n]-zp));

                rc=1000;
                aux1=20.0*(max(rc-d1/2.0,0.0)+min(d2/2.0-rc,0.0))/1000;

                tt=tt0+aux1;
                aux2=(gamma-1.0)/gamma*g/(R*tt0);
                
                rho[l,m,n]=p0/(R*tt)*(1.0-aux2*zc[l,m,n])**(1.0/(gamma-1.0)) #density
                p  [l,m,n]=p0* (1.0-aux2*zc[l,m,n])**(gamma/(gamma-1.0)) #pressure
                u  [l,m,n]=0.0 #x-velocity
                v  [l,m,n]=0.0 #y-velocity
                w  [l,m,n]=0.0 #z-velocity
                phi[l,m,n]=0.0 #solute

# %% [markdown]
# Now, the configuration and initial condition (and equilibrium) files are written:

# %%
write_config(folder_case, fname_config, FinalTime, DumpTime, CFL, Order, xcells, ycells, zcells, SizeX, SizeY, SizeZ, Face_1, Face_2, Face_3, Face_4, Face_5, Face_6, u_x, u_y, u_z)
write_equilibrium(folder_case, fname_eq, xcells, ycells, zcells, xc, yc, zc, ue, ve, we, rhoe, pe)       
write_initial(folder_case, fname_ini, xcells, ycells, zcells, xc, yc, zc, u, v, w, rho, p, phi)

# %% [markdown]
# ### Compilation and execution
#
# The program is compiled and executed:

# %%
compile_program_jupyter()
print("Program is running...")
run_program(folder_exe+"./caelum "+folder_case)
restore_file(folder_lib+'/definitions.h')
# Out:
# Running clean command...
# rm -f lib/preproc.o lib/ibmutils.o lib/mathutils.o lib/closures.o lib/reconst.o lib/numcore.o lib/solvers.o lib/postproc.o main.o caelum
#
# Running compile command...
# gcc -Wall -fopenmp -O3 -c -o lib/preproc.o lib/preproc.c
# gcc -Wall -fopenmp -O3 -c -o lib/ibmutils.o lib/ibmutils.c
# gcc -Wall -fopenmp -O3 -c -o lib/mathutils.o lib/mathutils.c
# gcc -Wall -fopenmp -O3 -c -o lib/closures.o lib/closures.c
# gcc -Wall -fopenmp -O3 -c -o lib/reconst.o lib/reconst.c
# gcc -Wall -fopenmp -O3 -c -o lib/numcore.o lib/numcore.c
# gcc -Wall -fopenmp -O3 -c -o lib/solvers.o lib/solvers.c
# gcc -Wall -fopenmp -O3 -c -o lib/postproc.o lib/postproc.c
# gcc -Wall -fopenmp -O3 -c -o main.o main.c
# gcc -Wall -fopenmp -O3 -o caelum lib/preproc.o lib/ibmutils.o lib/mathutils.o lib/closures.o lib/reconst.o lib/numcore.o lib/solvers.o lib/postproc.o main.o -lm
# Compilation successful
# Program is running...
# Program output:
# The number of threads is set to 24.
# Thread 0 of 24 is checked.
# Thread 1 of 24 is checked.
# Thread 22 of 24 is checked.
# Thread 16 of 24 is checked.
# Thread 18 of 24 is checked.
# Thread 12 of 24 is checked.
# Thread 23 of 24 is checked.
# Thread 17 of 24 is checked.
# Thread 19 of 24 is checked.
# Thread 21 of 24 is checked.
# Thread 7 of 24 is checked.
# Thread 10 of 24 is checked.
# Thread 9 of 24 is checked.
# Thread 14 of 24 is checked.
# Thread 20 of 24 is checked.
# Thread 6 of 24 is checked.
# Thread 2 of 24 is checked.
# Thread 8 of 24 is checked.
# Thread 3 of 24 is checked.
# Thread 4 of 24 is checked.
# Thread 15 of 24 is checked.
# Thread 11 of 24 is checked.
# Thread 13 of 24 is checked.
# Thread 5 of 24 is checked.
#
# Authors:
#  - Adrián Navas Montilla
#  - Isabel Echeverribar
# Copyright (C) 2018-2019 The authors.
#
# License type: Creative Commons Attribution-NonCommercial-NoDerivs 3.0 Spain (CC BY-NC-ND 3.0 ES under the following terms:
#
#  - Attribution — You must give appropriate credit and provide a link to the license.
#  - NonCommercial — You may not use the material for commercial purposes.
#  - NoDerivatives — If you remix, transform, or build upon the material, you may not distribute the modified material unless explicit permission of the authors is provided.
#
# Disclaimer: This software is distributed for research and/or academic purposes, WITHOUT ANY WARRANTY. In no event shall the authors be liable for any claim, damages or other liability, arising from, out of or in connection with the software or the use or other dealings in this software.
#
#  SIMULATION SETUP:
#  Folder path: /home/pc/Escritorio/pr/EHOW3D_public/python/../caseCollidingBub/
#  WENO reconstruction of order 7 is chosen.
#  Final time: 800.000000
#  CFL: 0.450000
#  Number of cells X: 100
#  Number of cells Y: 1
#  Number of cells Z: 50
#  Domain size: 20000.000000 x 1000.000000 x 10000.000000
#  Boundaries (1: periodic, 2: user defined, 3: transmissive, 4: solid wall):
#  Face_1(-y): 4
#  Face_2(+x): 4
#  Face_3(+y): 4
#  Face_4(-x): 4
#  Face_5(-z): 4
#  Face_6(+z): 4
#
#  [OK]  Configuration file has been read
#  [!]  The number of cells in Y is lower than half-the order of accuracy (ycells < (order-1)/2). If you want a 1D or 2D simulation, please be sure that ycells=1.
#  [OK]  Memory has been allocated and mesh connectivity has been defined
#  [OK]  equilibrium.out file has been read
#  [OK]  initial.out file has been read
#  [OK]  An VTK has been dumped: /home/pc/Escritorio/pr/EHOW3D_public/python/../caseCollidingBub//out/inital_geo_mesh.vtk
#  [OK]  A VTK has been written: /home/pc/Escritorio/pr/EHOW3D_public/python/../caseCollidingBub//out/state000.vtk
#  [OK]  A *.out file has been written: /home/pc/Escritorio/pr/EHOW3D_public/python/../caseCollidingBub//out/state000.out
#
#  T= 0.0e+0. Initial data printed. Starting time loop.
#
#  T= 100.183063, dt= 0.247596
#  Total mass: M= 1.52443193039007e+11
#  Total energy: E= 3.46477205856609e+16
#  Mass error: (M-M0)/M0 = -2.24212618606417e-14
#  Energy error: (E-E0)/E0 = -2.29740942995658e-14
#
#  [OK]  A VTK has been written: /home/pc/Escritorio/pr/EHOW3D_public/python/../caseCollidingBub//out/state001.vtk
#  [OK]  A *.out file has been written: /home/pc/Escritorio/pr/EHOW3D_public/python/../caseCollidingBub//out/state001.out
#
#  T= 200.402312, dt= 0.245928
#  Total mass: M= 1.52443193039003e+11
#  Total energy: E= 3.46477205856601e+16
#  Mass error: (M-M0)/M0 = -4.58434729114906e-14
#  Energy error: (E-E0)/E0 = -4.64099794393240e-14
#
#  [OK]  A VTK has been written: /home/pc/Escritorio/pr/EHOW3D_public/python/../caseCollidingBub//out/state002.vtk
#  [OK]  A *.out file has been written: /home/pc/Escritorio/pr/EHOW3D_public/python/../caseCollidingBub//out/state002.out
#
#  T= 300.494654, dt= 0.252844
#  Total mass: M= 1.52443193039000e+11
#  Total energy: E= 3.46477205856593e+16
#  Mass error: (M-M0)/M0 = -6.86651144482151e-14
#  Energy error: (E-E0)/E0 = -6.97304168690340e-14
#
#  [OK]  A VTK has been written: /home/pc/Escritorio/pr/EHOW3D_public/python/../caseCollidingBub//out/state003.vtk
#  [OK]  A *.out file has been written: /home/pc/Escritorio/pr/EHOW3D_public/python/../caseCollidingBub//out/state003.out
#
#  T= 400.617719, dt= 0.249931
#  Total mass: M= 1.52443193038996e+11
#  Total energy: E= 3.46477205856585e+16
#  Mass error: (M-M0)/M0 = -9.14867559849397e-14
#  Energy error: (E-E0)/E0 = -9.28199588786479e-14
#
#  [OK]  A VTK has been written: /home/pc/Escritorio/pr/EHOW3D_public/python/../caseCollidingBub//out/state004.vtk
#  [OK]  A *.out file has been written: /home/pc/Escritorio/pr/EHOW3D_public/python/../caseCollidingBub//out/state004.out
#
#  T= 500.624879, dt= 0.248297
#  Total mass: M= 1.52443193038993e+11
#  Total energy: E= 3.46477205856577e+16
#  Mass error: (M-M0)/M0 = -1.14308397521664e-13
#  Energy error: (E-E0)/E0 = -1.15678605468166e-13
#
#  [OK]  A VTK has been written: /home/pc/Escritorio/pr/EHOW3D_public/python/../caseCollidingBub//out/state005.vtk
#  [OK]  A *.out file has been written: /home/pc/Escritorio/pr/EHOW3D_public/python/../caseCollidingBub//out/state005.out
#
#  T= 600.834353, dt= 0.253097
#  Total mass: M= 1.52443193038989e+11
#  Total energy: E= 3.46477205856569e+16
#  Mass error: (M-M0)/M0 = -1.37130039058389e-13
#  Energy error: (E-E0)/E0 = -1.38999042897876e-13
#
#  [OK]  A VTK has been written: /home/pc/Escritorio/pr/EHOW3D_public/python/../caseCollidingBub//out/state006.vtk
#  [OK]  A *.out file has been written: /home/pc/Escritorio/pr/EHOW3D_public/python/../caseCollidingBub//out/state006.out
#
#  T= 700.941536, dt= 0.253260
#  Total mass: M= 1.52443193038986e+11
#  Total energy: E= 3.46477205856561e+16
#  Mass error: (M-M0)/M0 = -1.59551300919031e-13
#  Energy error: (E-E0)/E0 = -1.61626794067297e-13
#
#  [OK]  A VTK has been written: /home/pc/Escritorio/pr/EHOW3D_public/python/../caseCollidingBub//out/state007.vtk
#  [OK]  A *.out file has been written: /home/pc/Escritorio/pr/EHOW3D_public/python/../caseCollidingBub//out/state007.out
#
#  Final time is T= 8.00000000000000e+02
#
#  [OK]  A VTK has been written: /home/pc/Escritorio/pr/EHOW3D_public/python/../caseCollidingBub//out/state008.vtk
#  [OK]  A *.out file has been written: /home/pc/Escritorio/pr/EHOW3D_public/python/../caseCollidingBub//out/state008.out
#
#   =)  Simulation completed!
#
# File restored from /home/pc/Escritorio/pr/EHOW3D_public/python/../lib/definitions.h.bak and backup removed

# %% [markdown]
# ### Reading data and plotting
#
# To read data, we use the function ```read_data_euler()``` which gives as output the numerical solution for all time levels, e.g.  $\rho(x_l,y_m,z_n,t_j)$ is ```rho[l,m,n,j]```, where ```j``` is the time level.
#
# This can be customized for each particular case.

# %%
os.remove(folder_out + "list_eq.out")
files = sorted(glob(folder_out + "/*.out"), key=lambda x: int(re.findall(r'\d+', os.path.basename(x))[0]))
lf=len(files)
print(files)

gamma=1.4
j=0
print("Printing figures in folder"+folder_out)
images = []  # List to hold all the images for the GIF
for fname in files:
    
    u, v, w, rho, p, phi, theta, E = read_data_euler(fname, xcells, ycells, zcells, lf, gamma, j)
                  
    filename = fname+"_theta2D"
    
    xp = xc[:,0,0]     
    zp = zc[0,0,:]      
    X, Y = np.meshgrid(xp, zp)    
    Srho=np.transpose(rho[:,0,:,j])
    Spres=np.transpose(p[:,0,:,j])
    Svel=np.transpose(np.sqrt(u[:,0,:,j]**2+w[:,0,:,j]**2))
    Senr=np.transpose(E[:,0,:,j])
    Sphi=np.transpose(phi[:,0,:,j])
    Su=np.transpose(u[:,0,:,j])
    Sth=np.transpose(theta[:,0,:,j])
    
    fig, ax = plt.subplots(figsize=(10, 5))   
    levels = np.linspace(280, 320, 16)
    #print(levels)
    plot1=ax.contour(X, Y, Sth, levels=levels,colors="k",linewidths=0.5)  
    plot1=ax.contourf(X, Y, Sth, 200, cmap='RdBu')   
    ax.set_title('Potential temperature')
    ax.set_xlabel("x") 
    ax.set_ylabel("z") 
    ax.set_aspect('equal', 'box')
    plot1.set_clim( 280, 320 )
    # Create colorbar
    cbar = plt.colorbar(plot1)
    cbar.ax.set_title('θ(K)')
    fig.text(0.15, 0.72, "θ_max="+str(round(np.max(Sth),3)), fontsize=9.5)
    fig.text(0.15, 0.68, "θ_min="+str(round(np.min(Sth),3)), fontsize=9.5)
    
    image_path = filename + ".png"
    fig.savefig(image_path,dpi=400)
    images.append(imageio.imread(image_path)) 
    
    j=j+1
         
gif_path = os.path.join(folder_out, "animation.gif")
imageio.mimsave(gif_path, images, duration=8, loop=0)  # Adjust the duration as needed
# Out:
# ['/home/pc/Escritorio/pr/EHOW3D_public/python/../caseCollidingBub//out/state000.out', '/home/pc/Escritorio/pr/EHOW3D_public/python/../caseCollidingBub//out/state001.out', '/home/pc/Escritorio/pr/EHOW3D_public/python/../caseCollidingBub//out/state002.out', '/home/pc/Escritorio/pr/EHOW3D_public/python/../caseCollidingBub//out/state003.out', '/home/pc/Escritorio/pr/EHOW3D_public/python/../caseCollidingBub//out/state004.out', '/home/pc/Escritorio/pr/EHOW3D_public/python/../caseCollidingBub//out/state005.out', '/home/pc/Escritorio/pr/EHOW3D_public/python/../caseCollidingBub//out/state006.out', '/home/pc/Escritorio/pr/EHOW3D_public/python/../caseCollidingBub//out/state007.out', '/home/pc/Escritorio/pr/EHOW3D_public/python/../caseCollidingBub//out/state008.out']
# Printing figures in folder/home/pc/Escritorio/pr/EHOW3D_public/python/../caseCollidingBub//out/
# /home/pc/Escritorio/pr/EHOW3D_public/python/../caseCollidingBub//out/state000.out file read
# /tmp/ipykernel_835051/158792761.py:45: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   images.append(imageio.imread(image_path))
# /home/pc/Escritorio/pr/EHOW3D_public/python/../caseCollidingBub//out/state001.out file read
# /home/pc/Escritorio/pr/EHOW3D_public/python/../caseCollidingBub//out/state002.out file read
# /home/pc/Escritorio/pr/EHOW3D_public/python/../caseCollidingBub//out/state003.out file read
# /home/pc/Escritorio/pr/EHOW3D_public/python/../caseCollidingBub//out/state004.out file read
# /home/pc/Escritorio/pr/EHOW3D_public/python/../caseCollidingBub//out/state005.out file read
# /home/pc/Escritorio/pr/EHOW3D_public/python/../caseCollidingBub//out/state006.out file read
# /home/pc/Escritorio/pr/EHOW3D_public/python/../caseCollidingBub//out/state007.out file read
# /home/pc/Escritorio/pr/EHOW3D_public/python/../caseCollidingBub//out/state008.out file read

# %% [markdown]
# And the resulting animation:
#
# ![Simulation GIF](../caseCollidingBub/out/animation.gif)
